# %%
import pandas as pd
from faker import Faker

faker = Faker()
faker.random_int(100, 1000)
        
data = [faker.random_int(10, 10000) for _ in range(100)]
# Out:
# [4307,
#  5328,
#  4068,
#  9847,
#  3087,
#  6243,
#  9360,
#  5322,
#  5878,
#  5540,
#  4709,
#  2260,
#  606,
#  4919,
#  5846,
#  3254,
#  8782,
#  120,
#  9196,
#  7072,
#  7286,
#  2328,
#  7966,
#  4322,
#  4217,
#  7775,
#  7234,
#  3639,
#  9630,
#  6926,
#  219,
#  5369,
#  832,
#  9732,
#  3526,
#  9733,
#  4525,
#  7125,
#  2650,
#  4236,
#  5235,
#  6974,
#  3467,
#  6403,
#  2561,
#  7159,
#  1973,
#  606,
#  4716,
#  6372,
#  9474,
#  8521,
#  2802,
#  5250,
#  2786,
#  1061,
#  457,
#  62,
#  410,
#  481,
#  3454,
#  734,
#  8705,
#  2085,
#  3974,
#  9394,
#  6617,
#  1304,
#  4019,
#  9003,
#  1104,
#  3630,
#  8827,
#  2984,
#  5840,
#  3262,
#  5910,
#  2579,
#  6682,
#  9147,
#  7030,
#  4959,
#  142,
#  2782,
#  3851,
#  7323,
#  1567,
#  6062,
#  9133,
#  8230,
#  4003,
#  1156,
#  6541,
#  6506,
#  9208,
#  8968,
#  5516,
#  1631,
#  2655,
#  2317]
